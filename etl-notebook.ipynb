# %%
# Import Dependencies
import pandas as pd
import requests
import json
from sqlalchemy import create_engine
import psycopg2
import pymongo
import datetime

# %%
# Create base url
base_url = "https://crashviewer.nhtsa.dot.gov/CrashAPI/analytics/GetInjurySeverityCounts?"

# Store parameters
fromYear = 2015
toYear = 2015

# build partial query url
partial_url = f"{base_url}fromCaseYear={fromYear}&toCaseYear={toYear}"

# %%
# Set up empty list to store data
state_ids = []
total_fatals = []

# Run query 50 times, changing 'state=' to pull data from all 50 states
for n in range(1,51):
    query_url = f"{partial_url}&state={n}&format=json"
    
    try:
        print(f"Querying state {n}...")
        response = requests.get(query_url).json()
        state_ids.append(n)
        total_fatals.append(response["Results"][0][0]["TotalFatalCounts"])
        
    except:
        print(f"State {n} not found. Trying next state...")
        total_fatals.append(None)
# Out:
# Querying state 1...
# Querying state 2...
# Querying state 3...
# State 3 not found. Trying next state...
# Querying state 4...
# Querying state 5...
# Querying state 6...
# Querying state 7...
# State 7 not found. Trying next state...
# Querying state 8...
# Querying state 9...
# Querying state 10...
# Querying state 11...
# Querying state 12...
# Querying state 13...
# Querying state 14...
# State 14 not found. Trying next state...
# Querying state 15...
# Querying state 16...
# Querying state 17...
# Querying state 18...
# Querying state 19...
# Querying state 20...
# Querying state 21...
# Querying state 22...
# Querying state 23...
# Querying state 24...
# Querying state 25...
# Querying state 26...
# Querying state 27...
# Querying state 28...
# Querying state 29...
# Querying state 30...
# Querying state 31...
# Querying state 32...
# Querying state 33...
# Querying state 34...
# Querying state 35...
# Querying state 36...
# Querying state 37...
# Querying state 38...
# Querying state 39...
# Querying state 40...
# Querying state 41...
# Querying state 42...
# Querying state 43...
# Querying state 44...
# Querying state 45...
# Querying state 46...
# Querying state 47...
# Querying state 48...
# Querying state 49...
# Querying state 50...

# %%
# Create dictionary from lists
accident_dict = {
    "state_id": state_ids,
    "total_fatalaties": total_fatals
}

accidentData = pd.DataFrame(accident_dict)

# %%
# Read in binge drinking data
binge_drinking = pd.read_csv("Resources/BingeDrinkingPrevalence.csv")

# Preview dataset
binge_drinking.head()
# Out:
#   State  Percentage
# 0    AL        12.2
# 1    AK        20.0
# 2    AZ        15.0
# 3    AR        15.2
# 4    CA        16.7

# %%
# Read in state gender distribution data
gender_dist = pd.read_csv("Resources/StatePop_GenderDist.csv")

# Preview dataset
gender_dist.head()
# Out:
#         Location       Male     Female      Total  Footnotes
# 0  United States  152799800  159978200  312777900        1.0
# 1        Alabama    2276300    2453800    4730100        NaN
# 2         Alaska     363500     344000     707500        NaN
# 3        Arizona    3260100    3395100    6655100        NaN
# 4       Arkansas    1401000    1481300    2882300        NaN

# %%
# find gender ratio, drop US total from data
gender_dist=gender_dist.drop(0)

# %%
# extract only the data we need from gender_dist table
gender_ratio = (gender_dist['Male']/gender_dist['Female'])

# %%
# Merge the data into a single set
merged_data=pd.merge(accidentData, binge_drinking, right_index=True, left_index=True)
merged_data=merged_data.set_index('state_id')
merged_data.head()
# Out:
#           total_fatalaties State  Percentage
# state_id
# 1                    850.0    AL        12.2
# 2                     65.0    AK        20.0
# 3                      NaN    AZ        15.0
# 4                    897.0    AR        15.2
# 5                    550.0    CA        16.7

# %%
# Add in gender ratio data
merged_data['Male/Female']=gender_ratio

# %%
# final cleanup
merged_data=merged_data[['State', 'Male/Female', 'Percentage', 'total_fatalaties']]
merged_data=merged_data.rename(columns={'Percentage': 'Binge Drinking %', 'total_fatalaties': 'Total Vehicle Fatalaties'})
merged_data.head(50)
# Out:
#                          State  Male/Female  Binge Drinking %  \
# state_id
# 1                           AL     0.927663              12.2
# 2                           AK     1.056686              20.0
# 3                           AZ     0.960237              15.0
# 4                           AR     0.945791              15.2
# 5                           CA     0.971978              16.7
# 6                           CO     0.993549              18.1
# 7                           CT     0.949826              18.3
# 8                           DE     0.917519              15.8
# 9         District of Columbia     0.905734              24.4
# 10                          FL     0.936498              17.2
# 11                          GA     0.928858              15.8
# 12                          HI     0.961705              19.8
# 13                          ID     0.989176              14.8
# 14                          IL     0.949498              20.8
# 15                          IN     0.959707              16.6
# 16                          IA     0.980456              21.3
# 17                          KS     0.973791              16.5
# 18                          KY     0.955533              16.1
# 19                          LA     0.933052              18.0
# 20                          ME     0.957002              20.2
# 21                          MD     0.921948              14.7
# 22                          MA     0.942170              18.7
# 23                          MI     0.958027              19.8
# 24                          MN     0.987775              20.5
# 25                          MS     0.915346              12.5
# 26                          MO     0.952084              17.7
# 27                          MT     1.007784              21.3
# 28                          NE     0.984884              20.4
# 29                          NV     0.988458              14.5
# 30                          NH     0.980923              17.8
# 31                          NJ     0.946310              17.0
# 32                          NM     0.967234              13.6
# 33                          NY     0.938512              17.6
# 34                          NC     0.932593              14.6
# 35                          ND     1.035304              24.9
# 36                          OH     0.951933              19.5
# 37                          OK     0.962704              13.6
# 38                          OR     0.968004              17.7
# 39                          PA     0.945437              18.5
# 40                          RI     0.939209              17.0
# 41                          SC     0.930984              16.3
# 42                          SD     1.003142              17.9
# 43                          TN     0.938139              10.9
# 44                          TX     0.966324              16.1
# 45                          UT     1.009690              11.4
# 46                          VT     0.976378              19.0
# 47                          VA     0.935595              17.0
# 48                          WA     0.986723              16.6
# 49                          WV     0.960066              11.8
# 50                          WI     0.981493              24.4
#
#           Total Vehicle Fatalaties
# state_id
# 1                            850.0
# 2                             65.0
# 3                              NaN
# 4                            897.0
# 5                            550.0
# 6                           3387.0
# 7                              NaN
# 8                            547.0
# 9                            270.0
# 10                           131.0
# 11                            23.0
# 12                          2938.0
# 13                          1432.0
# 14                             NaN
# 15                            93.0
# 16                           216.0
# 17                           998.0
# 18                           817.0
# 19                           320.0
# 20                           355.0
# 21                           761.0
# 22                           752.0
# 23                           156.0
# 24                           520.0
# 25                           344.0
# 26                           967.0
# 27                           411.0
# 28                           677.0
# 29                           870.0
# 30                           224.0
# 31                           246.0
# 32                           326.0
# 33                           114.0
# 34                           561.0
# 35                           298.0
# 36                          1136.0
# 37                          1379.0
# 38                           131.0
# 39                          1110.0
# 40                           645.0
# 41                           446.0
# 42                          1200.0
# 43                           310.0
# 44                            45.0
# 45                           979.0
# 46                           134.0
# 47                           962.0
# 48                          3582.0
# 49                           278.0
# 50                            57.0

# %%
alcohol_data=merged_data.rename(columns={'Male/Female': 'Male_Female_Ratio', 'Binge Drinking %': 'Binge_Drinking_Pct', 'Total Vehicle Fatalaties': 'Total_Vehicle_Fatalities'})
alcohol_data.head(50)
# Out:
#                          State  Male_Female_Ratio  Binge_Drinking_Pct  \
# state_id
# 1                           AL           0.927663                12.2
# 2                           AK           1.056686                20.0
# 3                           AZ           0.960237                15.0
# 4                           AR           0.945791                15.2
# 5                           CA           0.971978                16.7
# 6                           CO           0.993549                18.1
# 7                           CT           0.949826                18.3
# 8                           DE           0.917519                15.8
# 9         District of Columbia           0.905734                24.4
# 10                          FL           0.936498                17.2
# 11                          GA           0.928858                15.8
# 12                          HI           0.961705                19.8
# 13                          ID           0.989176                14.8
# 14                          IL           0.949498                20.8
# 15                          IN           0.959707                16.6
# 16                          IA           0.980456                21.3
# 17                          KS           0.973791                16.5
# 18                          KY           0.955533                16.1
# 19                          LA           0.933052                18.0
# 20                          ME           0.957002                20.2
# 21                          MD           0.921948                14.7
# 22                          MA           0.942170                18.7
# 23                          MI           0.958027                19.8
# 24                          MN           0.987775                20.5
# 25                          MS           0.915346                12.5
# 26                          MO           0.952084                17.7
# 27                          MT           1.007784                21.3
# 28                          NE           0.984884                20.4
# 29                          NV           0.988458                14.5
# 30                          NH           0.980923                17.8
# 31                          NJ           0.946310                17.0
# 32                          NM           0.967234                13.6
# 33                          NY           0.938512                17.6
# 34                          NC           0.932593                14.6
# 35                          ND           1.035304                24.9
# 36                          OH           0.951933                19.5
# 37                          OK           0.962704                13.6
# 38                          OR           0.968004                17.7
# 39                          PA           0.945437                18.5
# 40                          RI           0.939209                17.0
# 41                          SC           0.930984                16.3
# 42                          SD           1.003142                17.9
# 43                          TN           0.938139                10.9
# 44                          TX           0.966324                16.1
# 45                          UT           1.009690                11.4
# 46                          VT           0.976378                19.0
# 47                          VA           0.935595                17.0
# 48                          WA           0.986723                16.6
# 49                          WV           0.960066                11.8
# 50                          WI           0.981493                24.4
#
#           Total_Vehicle_Fatalities
# state_id
# 1                            850.0
# 2                             65.0
# 3                              NaN
# 4                            897.0
# 5                            550.0
# 6                           3387.0
# 7                              NaN
# 8                            547.0
# 9                            270.0
# 10                           131.0
# 11                            23.0
# 12                          2938.0
# 13                          1432.0
# 14                             NaN
# 15                            93.0
# 16                           216.0
# 17                           998.0
# 18                           817.0
# 19                           320.0
# 20                           355.0
# 21                           761.0
# 22                           752.0
# 23                           156.0
# 24                           520.0
# 25                           344.0
# 26                           967.0
# 27                           411.0
# 28                           677.0
# 29                           870.0
# 30                           224.0
# 31                           246.0
# 32                           326.0
# 33                           114.0
# 34                           561.0
# 35                           298.0
# 36                          1136.0
# 37                          1379.0
# 38                           131.0
# 39                          1110.0
# 40                           645.0
# 41                           446.0
# 42                          1200.0
# 43                           310.0
# 44                            45.0
# 45                           979.0
# 46                           134.0
# 47                           962.0
# 48                          3582.0
# 49                           278.0
# 50                            57.0

# %%
# Create database connection
engine = create_engine('postgresql+psycopg2://postgres:Getfuzzy1@localhost:5434/alcohol_etl_db')

# %%
# confirm tables
engine.table_names()
# Out:
# ['alcohol_etl', 'alcohol_etl_db']

# %%
alcohol_data.to_sql(name='alcohol_etl_db', con=engine, if_exists='append', index=True)

# %%
pd.read_sql_query('select * from alcohol_etl_db', con=engine).head(50)
# Out:
#     state_id                 State  Male_Female_Ratio  Binge_Drinking_Pct  \
# 0          1                    AL           0.927663                12.2
# 1          2                    AK           1.056686                20.0
# 2          3                    AZ           0.960237                15.0
# 3          4                    AR           0.945791                15.2
# 4          5                    CA           0.971978                16.7
# 5          6                    CO           0.993549                18.1
# 6          7                    CT           0.949826                18.3
# 7          8                    DE           0.917519                15.8
# 8          9  District of Columbia           0.905734                24.4
# 9         10                    FL           0.936498                17.2
# 10        11                    GA           0.928858                15.8
# 11        12                    HI           0.961705                19.8
# 12        13                    ID           0.989176                14.8
# 13        14                    IL           0.949498                20.8
# 14        15                    IN           0.959707                16.6
# 15        16                    IA           0.980456                21.3
# 16        17                    KS           0.973791                16.5
# 17        18                    KY           0.955533                16.1
# 18        19                    LA           0.933052                18.0
# 19        20                    ME           0.957002                20.2
# 20        21                    MD           0.921948                14.7
# 21        22                    MA           0.942170                18.7
# 22        23                    MI           0.958027                19.8
# 23        24                    MN           0.987775                20.5
# 24        25                    MS           0.915346                12.5
# 25        26                    MO           0.952084                17.7
# 26        27                    MT           1.007784                21.3
# 27        28                    NE           0.984884                20.4
# 28        29                    NV           0.988458                14.5
# 29        30                    NH           0.980923                17.8
# 30        31                    NJ           0.946310                17.0
# 31        32                    NM           0.967234                13.6
# 32        33                    NY           0.938512                17.6
# 33        34                    NC           0.932593                14.6
# 34        35                    ND           1.035304                24.9
# 35        36                    OH           0.951933                19.5
# 36        37                    OK           0.962704                13.6
# 37        38                    OR           0.968004                17.7
# 38        39                    PA           0.945437                18.5
# 39        40                    RI           0.939209                17.0
# 40        41                    SC           0.930984                16.3
# 41        42                    SD           1.003142                17.9
# 42        43                    TN           0.938139                10.9
# 43        44                    TX           0.966324                16.1
# 44        45                    UT           1.009690                11.4
# 45        46                    VT           0.976378                19.0
# 46        47                    VA           0.935595                17.0
# 47        48                    WA           0.986723                16.6
# 48        49                    WV           0.960066                11.8
# 49        50                    WI           0.981493                24.4
#
#     Total_Vehicle_Fatalities
# 0                      850.0
# 1                       65.0
# 2                        NaN
# 3                      897.0
# 4                      550.0
# 5                     3387.0
# 6                        NaN
# 7                      547.0
# 8                      270.0
# 9                      131.0
# 10                      23.0
# 11                    2938.0
# 12                    1432.0
# 13                       NaN
# 14                      93.0
# 15                     216.0
# 16                     998.0
# 17                     817.0
# 18                     320.0
# 19                     355.0
# 20                     761.0
# 21                     752.0
# 22                     156.0
# 23                     520.0
# 24                     344.0
# 25                     967.0
# 26                     411.0
# 27                     677.0
# 28                     870.0
# 29                     224.0
# 30                     246.0
# 31                     326.0
# 32                     114.0
# 33                     561.0
# 34                     298.0
# 35                    1136.0
# 36                    1379.0
# 37                     131.0
# 38                    1110.0
# 39                     645.0
# 40                     446.0
# 41                    1200.0
# 42                     310.0
# 43                      45.0
# 44                     979.0
# 45                     134.0
# 46                     962.0
# 47                    3582.0
# 48                     278.0
# 49                      57.0
